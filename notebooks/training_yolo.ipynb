# %%
# !git clone https://github.com/mkeohane01/object_detection
# Out:
# Cloning into 'object_detection'...
# remote: Enumerating objects: 658, done.
# remote: Counting objects: 100% (658/658), done.
# remote: Compressing objects: 100% (501/501), done.
# remote: Total 658 (delta 5), reused 655 (delta 5), pack-reused 0
# Receiving objects: 100% (658/658), 18.41 MiB | 34.34 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16517, done.
# remote: Counting objects: 100% (115/115), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 16517 (delta 47), reused 54 (delta 17), pack-reused 16402
# Receiving objects: 100% (16517/16517), 15.17 MiB | 25.14 MiB/s, done.
# Resolving deltas: 100% (11304/11304), done.

# %%
import os
os.chdir("/content")
# !pwd
# Out:
# /content

# %%
# !unzip trainexp.zip -d trainexp_unzip
# Out:
# Archive:  trainexp.zip
#    creating: trainexp_unzip/content/yolov5/runs/train/exp/
#   inflating: trainexp_unzip/content/yolov5/runs/train/exp/val_batch0_pred.jpg
#   inflating: trainexp_unzip/content/yolov5/runs/train/exp/P_curve.png
#   inflating: trainexp_unzip/content/yolov5/runs/train/exp/opt.yaml
#   inflating: trainexp_unzip/content/yolov5/runs/train/exp/events.out.tfevents.1710209987.3f9d35030a86.890.0
#   inflating: trainexp_unzip/content/yolov5/runs/train/exp/val_batch0_labels.jpg
#   inflating: trainexp_unzip/content/yolov5/runs/train/exp/results.png
#    creating: trainexp_unzip/content/yolov5/runs/train/exp/weights/
#   inflating: trainexp_unzip/content/yolov5/runs/train/exp/weights/last.pt
#   inflating: trainexp_unzip/content/yolov5/runs/train/exp/weights/best.pt
#   inflating: trainexp_unzip/content/yolov5/runs/train/exp/train_batch0.jpg
#   inflating: trainexp_unzip/content/yolov5/runs/train/exp/val_batch1_labels.jpg
# ...

# %%
# !python yolov5/train.py --data dataset.yaml --weights yolov5s.pt --epochs 100 --batch 4 --freeze 10
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.2/721.2 kB 4.7 MB/s eta 0:00:00
# ...
# 2024-03-12 02:19:39.397583: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-12 02:19:39.397641: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-12 02:19:39.399788: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# requirements: Ultralytics requirement ['gitpython'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 17.7 MB/s eta 0:00:00
# ...
#
# ...

# %%
# !zip -r /content/testexp.zip /content/yolov5/runs/val/exp3
# Out:
#   adding: content/yolov5/runs/val/exp3/ (stored 0%)
#   adding: content/yolov5/runs/val/exp3/val_batch0_pred.jpg (deflated 6%)
#   adding: content/yolov5/runs/val/exp3/P_curve.png (deflated 9%)
#   adding: content/yolov5/runs/val/exp3/val_batch0_labels.jpg (deflated 6%)
#   adding: content/yolov5/runs/val/exp3/val_batch1_labels.jpg (deflated 6%)
#   adding: content/yolov5/runs/val/exp3/val_batch1_pred.jpg (deflated 6%)
#   adding: content/yolov5/runs/val/exp3/PR_curve.png (deflated 15%)
#   adding: content/yolov5/runs/val/exp3/F1_curve.png (deflated 10%)
#   adding: content/yolov5/runs/val/exp3/confusion_matrix.png (deflated 30%)
#   adding: content/yolov5/runs/val/exp3/R_curve.png (deflated 11%)

# %%
# !python yolov5/val.py --data dataset.yaml --weights /content/trainexp_unzip/content/yolov5/runs/train/exp/weights/best.pt
# Out:
# val: data=/content/yolov5/data/dataset.yaml, weights=['/content/trainexp_unzip/content/yolov5/runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-294-gdb125a20 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /content/object_detection/data/yolo-data/labels/test... 50 images, 3 backgrounds, 0 corrupt: 100% 50/50 [00:00<00:00, 1347.25it/s]
# val: New cache created: /content/object_detection/data/yolo-data/labels/test.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:03<00:00,  1.71s/it]
# ...
